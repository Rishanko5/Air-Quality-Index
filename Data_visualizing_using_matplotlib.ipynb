# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

#Sample data for energy consumption over 6 months (in Mich)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
energy_consumption= [1200, 1300, 1100, 1500, 1400, 1600]


#Create a Line plot
plt.plot(months, energy_consumption, marker='o', color='b', linestyle='--')

#Add titles and Labels
plt.title('Energy Consumption Over 6 Months')
plt.xlabel('Month')
plt.ylabel('Energy Consumption (MWh)')
plt.show()

# %%
plt.pie(energy_consumption, labels=energy_sources, autopct='%1.1f%%', startangle=90)

plt.title('Energy Consumption by Source')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1657208fd6b6> in <cell line: 1>()
# ----> 1 plt.pie(energy_consumption, labels=energy_sources, autopct='%1.1f%%', startangle=90)
#       2
#       3 plt.title('Energy Consumption by Source')
#       4
#       5 plt.show()
#
# NameError: name 'energy_sources' is not defined

# %%
import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
energy_consumption= [1200, 1300, 1100, 1500, 1400, 1600]

plt.pie(energy_consumption, labels=months, autopct='%1.1f%%', startangle=90)

plt.title('Energy Consumption Distribution Over 6 Months')

plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt

#Y-axis values

y1= [2, 3, 4.5]

#Y-axis values

y2= [1, 1.5, 5]

#Function to plot

plt.plot(y1)

plt.plot(y2)

#Function add a Legend

plt.legend(["blue", "green"], loc ="lower right")

#function to show the plot

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Sample Data
data = {
    "Energy Source": ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass", "Nuclear"],
    "Energy Consumption (MWh)": [1200, 1400, 2900, 1800, 2500, 3200],
    "Cost (Million $)": [200, 400, 350, 150, 250, 300]
}

# Create a DataFrame
energy_df = pd.DataFrame(data)

# Pair plot (ignoring non-numeric columns)
sns.pairplot(energy_df, vars=["Energy Consumption (MWh)", "Cost (Million $)"], diag_kind="kde")

# Show the plot
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#Creating a DataFrame for pair plot
data = {
"Solar": [1200, 1500, 1300],
"Wind": [3400, 3600, 3200],
"Hydropower": [2900, 3100, 2800],
"Blomass": [2500, 2700, 2400]
}

df =pd.DataFrame(data)
#a Ceate a pair plot
sns.pairplot(df)
plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.show('Correaltion Between Energy Sources')
plt.show()

# %%
#create a box plot
sns.boxplot(data=df)
plt.title('Distribution of Energy Consumption')

plt.show()

# %%
sns.violinplot(data=df)
plt.title('Violin Plot of energy cosumption Distribuition')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
energy_values =[100,200,300,400,500]
carbon_emissions = [10,20,25,40,50,]

de_reg = pd.DataFrame({
    'Energy Cosumption': energy_values,
    'Carbon Emissions': carbon_emissions
})

sns.regplot(x='Energy Cosumption', y='Carbon Emissions', data=de_reg)
plt.title('Relationship between Energy Cosumption and Carbon Emissions')
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()

ax = plt.axes(projection='3d')

z= np.linspace(0,5,1000)
x= np.sin(25*z)
y= np.cos(25*z)

ax.plot3D(x,y,z, 'gray')
ax.set_title('3D Line Plot')
plt.show()

# %%
df.describe ()
# Out:
#              Solar    Wind   Hydropower      Blomass
# count     3.000000     3.0     3.000000     3.000000
# mean   1333.333333  3400.0  2933.333333  2533.333333
# std     152.752523   200.0   152.752523   152.752523
# min    1200.000000  3200.0  2800.000000  2400.000000
# 25%    1250.000000  3300.0  2850.000000  2450.000000
# 50%    1300.000000  3400.0  2900.000000  2500.000000
# 75%    1400.000000  3500.0  3000.000000  2600.000000
# max    1500.000000  3600.0  3100.000000  2700.000000

# %%
df.isnull().sum()
# Out:
# Solar         0
# Wind          0
# Hydropower    0
# Blomass       0
# dtype: int64

# %%
df = pd.read_csv('IRIS.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sepal_width'].plot(kind='hist', bins=20, title='sepal_width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
sns.pairplot(df, hue = 'species', palette="husl",size=2)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df = pd.read_csv("IRIS.csv")


df['species'] = df['species'].astype('category').cat.codes

corr = df.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x='petal_length', y='petal_width', data=df, hue='species')
plt.show()
